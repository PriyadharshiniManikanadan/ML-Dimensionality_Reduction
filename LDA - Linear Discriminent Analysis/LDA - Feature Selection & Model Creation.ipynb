# %% [markdown]
# # LDA - Linear Discriminent Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Importing Dataset

raw_data = pd.read_csv("CKD.csv")
raw_data
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]

# %%
df = raw_data

# %%
df = pd.get_dummies(df, dtype=int, drop_first=True)

# %%
indep_x = df.drop('classification_yes',axis = 1)
dep_y = df['classification_yes']

# %%
def cm_prediction(classifier,x_test,y_test):
    y_pred = classifier.predict(x_test)
    cm = confusion_matrix(y_test,y_pred)
    Accuracy = accuracy_score(y_test,y_pred)
    Report = classification_report(y_test,y_pred)
    return cm,Accuracy,Report

def logistic(x_train,y_train,x_test,y_test):
    classifier = LogisticRegression(random_state=0)
    classifier.fit(x_train,y_train)
    return cm_prediction(classifier,x_test,y_test)

def svm_linear(x_train,y_train,x_test,y_test):
    classifier = SVC(kernel='linear',random_state=0)
    classifier.fit(x_train,y_train)
    return cm_prediction(classifier,x_test,y_test)

def svm_nonlinear(x_train,y_train,x_test,y_test):
    classifier = SVC(kernel = 'rbf', random_state=0)
    classifier.fit(x_train,y_train)
    return cm_prediction(classifier,x_test,y_test)

def knn(x_train,y_train,x_test,y_test):
    classifier = KNeighborsClassifier(n_neighbors=5, metric = 'minkowski')
    classifier.fit(x_train,y_train)
    return cm_prediction(classifier,x_test,y_test)

def naive(x_train,y_train,x_test,y_test):   
    classifier = GaussianNB()
    classifier.fit(x_train,y_train)
    return cm_prediction(classifier,x_test,y_test)

def decision(x_train,y_train,x_test,y_test):
    classifier = DecisionTreeClassifier(criterion = 'entropy', random_state=0)
    classifier.fit(x_train,y_train)
    return cm_prediction(classifier,x_test,y_test)

def random(x_train,y_train,x_test,y_test):
    classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state=0)
    classifier.fit(x_train,y_train)
    return cm_prediction(classifier,x_test,y_test)

def LDA_results(acclog,accsvml,accsvmnl,accknn,accnav,accdc,accrf):
    LDAdataframe = pd.DataFrame(index = ['LDA'], columns = ['Logistic', 'SVM_l', 'SVM_nl', 'KNN',
                                                                                              'Naive','Decision','Random'])
    for index in LDAdataframe.index:
        LDAdataframe['Logistic'][index] = acclog
        LDAdataframe['SVM_l'][index] = accsvml
        LDAdataframe['SVM_nl'][index] = accsvmnl
        LDAdataframe['KNN'][index] = accknn
        LDAdataframe['Naive'][index] = accnav
        LDAdataframe['Decision'][index] = accdc
        LDAdataframe['Random'][index] = accrf
    return LDAdataframe

# %%
acclog =[] 
accsvml = []
accsvmnl = []
accknn = []
accnav = [] 
accdc = []
accrf = []

# %%
# Train Test Split
x_train,x_test,y_train,y_test = train_test_split(indep_x,dep_y,test_size = 0.2, random_state=0)
sc=StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train.shape[1]
# Out:
# 27

# %%
len(np.unique(y_train) -1 )
# Out:
# 2

# %%
max_components = min(x_train.shape[1], len(np.unique(y_train)) - 1)
max_components
# Out:
# 1

# %%
# Applying LDA

lda = LDA(n_components = max_components)
x_train_lda = lda.fit_transform(x_train,y_train)
x_test_lda = lda.transform(x_test)

# %% [markdown]
# ValueError: n_components cannot be larger than min(n_features, n_classes - 1)
# occurs because the n_components parameter in Linear Discriminant Analysis (LDA) is set to a value that exceeds the maximum allowable components.

# %%
# Calculate accuracies for each classifier


cm,Accuracy,Report = logistic(x_train_lda, y_train, x_test_lda, y_test)
acclog.append(Accuracy)

cm,Accuracy,Report = svm_linear(x_train_lda, y_train, x_test_lda, y_test)
accsvml.append(Accuracy)

cm,Accuracy,Report = svm_nonlinear(x_train_lda, y_train, x_test_lda, y_test)
accsvmnl.append(Accuracy)

cm,Accuracy,Report = knn(x_train_lda, y_train, x_test_lda, y_test)
accknn.append(Accuracy)

cm,Accuracy,Report = naive(x_train_lda, y_train, x_test_lda, y_test)
accnav.append(Accuracy)

cm,Accuracy,Report = decision(x_train_lda, y_train, x_test_lda, y_test)
accdc.append(Accuracy)

cm,Accuracy,Report = random(x_train_lda, y_train, x_test_lda, y_test)
accrf.append(Accuracy)

result = LDA_results(acclog[0],accsvml[0],accsvmnl[0],accknn[0],accnav[0],accdc[0],accrf[0])
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_5272\3939420337.py:47: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   LDAdataframe['Logistic'][index] = acclog
# C:\Users\priya\AppData\Local\Temp\ipykernel_5272\3939420337.py:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   LDAdataframe['SVM_l'][index] = accsvml
# C:\Users\priya\AppData\Local\Temp\ipykernel_5272\3939420337.py:49: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   LDAdataframe['SVM_nl'][index] = accsvmnl
# C:\Users\priya\AppData\Local\Temp\ipykernel_5272\3939420337.py:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   LDAdataframe['KNN'][index] = accknn
# C:\Users\priya\AppData\Local\Temp\ipykernel_5272\3939420337.py:51: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   LDAdataframe['Naive'][index] = accnav
# C:\Users\priya\AppData\Local\Temp\ipykernel_5272\3939420337.py:52: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   LDAdataframe['Decision'][index] = accdc
# C:\Users\priya\AppData\Local\Temp\ipykernel_5272\3939420337.py:53: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   LDAdataframe['Random'][index] = accrf

# %%
result
# Out:
#     Logistic   SVM_l  SVM_nl   KNN  Naive Decision  Random
# LDA    0.975  0.9625  0.9625  0.95  0.975   0.9625  0.9625

# %%
best_model_accuracy = result.max().max()  # Overall max accuracy
best_model_location = result.stack().idxmax()  # Find exact location (row, column) of max accuracy
best_model = best_model_location[1]  # This gives the exact column (model) name

# %%
if best_model == 'Logistic':
    best_model = LogisticRegression(random_state=0)
elif best_model == 'SVM_l':
    best_model = SVC(kernel = 'linear', random_state=0)
elif best_model == 'SVM_nl':
    best_model = SVC(kernel = 'rbf', random_state=0)
elif best_model == 'KNN':
    best_model = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p =2)
elif best_model == 'Naive':
    best_model = GaussianNB()
elif best_model == 'Decision':
    best_model = DecisionTreeClassifier(criterian = 'entropy', random_state=0)
elif best_model == 'Random':
    best_model = RandomFoprestClassifier(n_estimators = 10, criterion = 'entropy', random_state=0)

# %%
best_model.fit(x_train_lda, y_train)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# ### Save the Best Model

# %%
import pickle
with open('Final_LDA_model.pkl', 'wb') as file :
    pickle.dump((best_model,sc),file)

# %% [markdown]
# ### Getting User input

# %%
age_input=int(input("Age: "))
bp_input=int(input("Blood Pressure: "))
al_input=float(input("Albumin Level(al) (1/2/3/4): "))
su_input=input("Serum Creatinine(su): ")
bgr_input=float(input("bgr: "))
bu_input=int(input("Blood Urea(bu): "))
sc_input=float(input("Serum Creatinine(sc): "))
sod_input=float(input("Sodium(sod): "))
pot_input=float(input("Pottasium(pot): "))
hrmo_input=float(input("hor: "))
pcv_input=float(input("Packed Cell Volume(pcv): "))
wc_input=int(input("White Cells(wc): "))
rc_input=float(input("Creatinine Clearance Test(rc): "))
sg_b_input=float(input("Urinary Specific Gravity(sg): "))                                  
sg_c_input=float(input("Urinary Specific Gravity(sg): "))                                                 
sg_d_input=float(input("Urinary Specific Gravity(sg): "))
sg_e_input=float(input("Urinary Specific Gravity(sg): "))
rbc_normal_input=int(input("Red Blood Cell(rbc) - Abnormal 0 or 1: "))
pc_normal_input=(input("Protien Creatinine(pc) - Abnormal 0 or 1: "))
pcc_present_input=int(input("pcc - Not present 0 or 1: "))
ba_present_input=int(input("ba - Not present 0 or 1: "))
htn_yesy_input=int(input("htn No 0 or 1  "))
dm_yes_input=int(input("dm: No 0 or 1"))
cad_yes_input=int(input("cad: No 0 or 1"))
appet_yes_input=int(input("appet: Poor 0 or 1 "))
pe_yes_input=int(input("pe: No 0 or 1"))
ane_yes_input=int(input("ane: No 0 or 1"))

# %% [markdown]
# ### Preprocess the User Input

# %%
User_input_prepro = sc.fit_transform([[age_input,bp_input,al_input,su_input,bgr_input,bu_input,sc_input,sod_input,pot_input,hrmo_input,pcv_input,wc_input,rc_input,sg_b_input,sg_c_input,sg_d_input,sg_e_input,rbc_normal_input,pc_normal_input,pcc_present_input,ba_present_input,htn_yesy_input,dm_yes_input,cad_yes_input,appet_yes_input,pe_yes_input,ane_yes_input]])
User_input_prepro

# %% [markdown]
# ### Predictions

# %%
Predictions = best_model.predict([[age_input,bp_input,al_input,su_input,bgr_input,bu_input,sc_input,sod_input,pot_input,hrmo_input,pcv_input,wc_input,rc_input,sg_b_input,sg_c_input,sg_d_input,sg_e_input,rbc_normal_input,pc_normal_input,pcc_present_input,ba_present_input,htn_yesy_input,dm_yes_input,cad_yes_input,appet_yes_input,pe_yes_input,ane_yes_input]])
Predictions
